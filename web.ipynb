# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)

def scrape_myntra(url):
    driver.get(url)
    time.sleep(3)
 
    for _ in range(15):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)
    

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    products = []
    
    for item in soup.select('li.product-base'):
        try:
            brand_element = item.select_one('h3.product-brand').text.strip()
            name_element = item.select_one('h4.product-product').text.strip()
            price_element = item.select_one('span.product-discountedPrice').text.strip()
            image_element = item.select_one('img.img-responsive')
            image_url = image_element['data-src'] if 'data-src' in image_element.attrs else image_element['src']
            
            product = {
                'brand': brand_element if brand_element else "Brand not found",
                'name': name_element if name_element else "Name not found",
                'price': price_element if price_element else "Price not found",
                'image_url': image_url if image_url else "Image not found",
            }
            products.append(product)
        except Exception as e:
            print(f"Error scraping product: {str(e)}")
    
    return pd.DataFrame(products)

df = scrape_myntra("https://www.myntra.com/men-clothing")
print(df)
df.to_csv("myntra_products1.csv", index=False)
driver.quit()
# Out:
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
#         brand                         name     price  \
# 0  HIGHLANDER        Slim Fit Casual Shirt   Rs. 449
# 1    DAMENSCH  DEO-SOFT Deodorizing Trunks   Rs. 429
# 2      ONEWAY  Unisex Solid Cotton T-shirt   Rs. 559
# 3       Celio          Men Cargos Trousers  Rs. 1399
# 4    Roadster  Men Light Fade Skater Jeans  Rs. 1007
#
#                                            image_url
# 0  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 1  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 3  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 4  https://assets.myntassets.com/dpr_2,q_60,w_210...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time

options = webdriver.ChromeOptions()
options.add_argument("--headless") 
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)

def scrape_myntra(url):
    driver.get(url)
    time.sleep(3)
    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)
        
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    products = []
    

    for item in soup.select('li.product-base'):
        try:
            brand_element = item.select_one('h3.product-brand').text.strip()
            name_element = item.select_one('h4.product-product').text.strip()
            price_element = item.select_one('span.product-discountedPrice').text.strip()
            ori_price_element = item.select_one('span.product-discountedPrice').text
                                    
           
            image_element = item.select_one('img.img-responsive')
            image_url = image_element['data-src'] if 'data-src' in image_element.attrs else image_element['src']
            
            product = {
                'brand': brand_element,
                'name': name_element,
                'price': price_element,
                # 'image_url': image_url, -- not necessary
                'original_price': ori_price_element 
            }
            products.append(product)
        except Exception as e:
            print(f"Error scraping product: {str(e)}")
    
    return pd.DataFrame(products)

url = "https://www.myntra.com/men-clothing"
df = scrape_myntra(url)
print(df.head()) 
df.to_csv("myntra_products2.csv", index=False)  

driver.quit()
# Out:
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
#              brand                         name     price  \
# 0  U.S. Polo Assn.      Men Solid Casual Shirts  Rs. 1874
# 1       HIGHLANDER        Slim Fit Casual Shirt   Rs. 449
# 2           ONEWAY  Unisex Solid Cotton T-shirt   Rs. 559
# 3         DAMENSCH  DEO-SOFT Deodorizing Trunks   Rs. 429
# 4         Roadster  Men Light Fade Skater Jeans  Rs. 1007
#
#                                            image_url
# 0  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 1  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 2  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 3  https://assets.myntassets.com/dpr_2,q_60,w_210...
# 4  https://assets.myntassets.com/dpr_2,q_60,w_210...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time

options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)

def scrape_myntra(url):
    driver.get(url)
    time.sleep(3) 
    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)
        
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    products = []
    
    for item in soup.select('li.product-base'):
        try:
            brand_element = item.select_one('h3.product-brand').text.strip()
            name_element = item.select_one('h4.product-product').text.strip()
            price_element = item.select_one('span.product-discountedPrice').text.strip()
            ori_price_element = item.select_one('span.product-discountedPrice').text
            # image_element = item.select_one('img.img-responsive')
            # image_url = image_element['data-src'] if 'data-src' in image_element.attrs else image_element['src']
            
            product = {
                'brand': brand_element,
                'name': name_element,
                'price': price_element,
                'original_price': ori_price_element 
                # 'image_url': image_url,
            }
            products.append(product)
        except Exception as e:
            print(f"Error scraping product: {str(e)}")
    
    return pd.DataFrame(products)

url = "https://www.myntra.com/men-clothing"
df = scrape_myntra(url)
print(df.head())
df.to_csv("myntra_products4.csv", index=False)  

driver.quit()
# Out:
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
#              brand                         name     price original_price
# 0  U.S. Polo Assn.    Men Printed Casual Shirts  Rs. 1874       Rs. 1874
# 1  U.S. Polo Assn.      Men Solid Casual Shirts  Rs. 1874       Rs. 1874
# 2           ONEWAY  Unisex Solid Cotton T-shirt   Rs. 559        Rs. 559
# 3       HIGHLANDER        Slim Fit Casual Shirt   Rs. 449        Rs. 449
# 4         Roadster  Men Light Fade Skater Jeans  Rs. 1007       Rs. 1007

# %%
options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)
def scrape_myntra(url):
    driver.get(url)
    time.sleep(3)
    
  
    for _ in range(20):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    products = []
 
    for item in soup.select('li.product-base'):
        try:
            brand_element = item.select_one('h3.product-brand').text
            name_element = item.select_one('h4.product-product').text
            price_element = item.select_one('span.product-discountedPrice').text
            
            image_element = item.select_one('img.img-responsive')
            image_url = image_element['data-src'] if 'data-src' in image_element.attrs else image_element['src']
            
            product = {
                'brand': brand_element,
                'name': name_element,
                'price': price_element,
                'image_url': image_url,
            }
            products.append(product)
        except Exception as e:
            print(f"Error scraping product: {e}")
    
    return pd.DataFrame(products)

base_url = "https://www.myntra.com/men-clothing?p="
all_products = []

for page in range(1, 10):
    df_page = scrape_myntra(f"{base_url}{page}")
    all_products.append(df_page)

final_df = pd.concat(all_products)
final_df.to_csv("myntra_all_products.csv", index=False)
driver.quit()
# Out:
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'text'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# Error scraping product: 'NoneType' object has no attribute 'attrs'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 46
#      43 all_products = []
#      45 for page in range(1, 10):
# ---> 46     df_page = scrape_myntra(f"{base_url}{page}")
#      47     all_products.append(df_page)
#      49 final_df = pd.concat(all_products)
#
# Cell In[3], line 16, in scrape_myntra(url)
#      14 for _ in range(20):
#      15     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
# ---> 16     time.sleep(2)
#      18 soup = BeautifulSoup(driver.page_source, 'html.parser')
#      19 products = []
#
# KeyboardInterrupt:
